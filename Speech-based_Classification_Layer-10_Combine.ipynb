# %% [markdown]
# # Library Imports

# %%
import pandas as pd

# %% [markdown]
# # Import Datasets

# %%
label_1_csv_url = "/content/drive/MyDrive/#Semester07/CS4622/ML Project/speech-based-classification-layer-10/label_1.csv"
label_2_csv_url = "/content/drive/MyDrive/#Semester07/CS4622/ML Project/speech-based-classification-layer-10/label_2.csv"
label_3_csv_url = "/content/drive/MyDrive/#Semester07/CS4622/ML Project/speech-based-classification-layer-10/label_3.csv"
label_4_csv_url = "/content/drive/MyDrive/#Semester07/CS4622/ML Project/speech-based-classification-layer-10/label_4.csv"

label_1_data = pd.read_csv(label_1_csv_url)
label_2_data = pd.read_csv(label_2_csv_url)
label_3_data = pd.read_csv(label_3_csv_url)
label_4_data = pd.read_csv(label_4_csv_url)

label_1_data.head()
# Out:
#    ID  feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   1  -0.063023   0.085030  -0.057909   0.024293   0.028695  -0.113796
# 1   2  -0.036403   0.115930  -0.066521   0.045771  -0.027250  -0.164679
# 2   3   0.030672   0.045321  -0.163811   0.142376  -0.125894  -0.083943
# 3   4  -0.000984   0.080593  -0.067086   0.005251  -0.141851  -0.125211
# 4   5   0.059806   0.088846  -0.058021   0.133098  -0.083380  -0.026724
#
#    feature_7  feature_8  feature_9  ...  feature_760  feature_761  \
# 0   0.028477  -0.006041  -0.132434  ...     0.078897     0.120168
# 1   0.023611   0.056512  -0.171498  ...     0.042576     0.006788
# 2  -0.039693  -0.004867  -0.127951  ...     0.038063     0.070423
# 3  -0.016161   0.106323  -0.203491  ...     0.028166    -0.073713
# 4  -0.033793  -0.004055  -0.057890  ...     0.026333     0.012204
#
#    feature_762  feature_763  feature_764  feature_765  feature_766  \
# ...

# %%
Classification_Layer_10 = label_1_data[["ID", "label_1"]].copy()

Classification_Layer_10["label_2"] = label_2_data["label_2"]
Classification_Layer_10["label_3"] = label_3_data["label_3"]
Classification_Layer_10["label_4"] = label_4_data["label_4"]

Classification_Layer_10.head()
# Out:
#    ID  label_1  label_2  label_3  label_4
# 0   1       18     25.0        1        6
# 1   2       27     31.0        1        6
# 2   3       22     24.0        1        6
# 3   4       48     24.0        1        6
# 4   5       45     27.0        1        6

# %%
file_path = "/content/drive/MyDrive/#Semester07/CS4622/ML Project/speech-based-classification-layer-10/Classification_Layer_10.csv"

# Save the DataFrame to a CSV file
Classification_Layer_10.to_csv(file_path, index=False)
